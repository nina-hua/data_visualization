# %% [markdown]
# Exploring states of the United States that produce sugar in relationship to the percentage of obese adults in corresponding states.

# %%
import pandas as pd 
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go

# %%
# read in excel file 
excelFile = pd.ExcelFile('../data/week_5_6/Ag_Census_Map_data_07172015.xlsx')
# parse through multiple sheets of excel 
agri_df = {}
for sheet_name in excelFile.sheet_names:
    agri_df[sheet_name] = excelFile.parse(sheet_name)

# %%
obese = pd.read_csv('../data/week_5_6/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')

# %% [markdown]
# ## Cleaning

# %%
# filter obesity data to include data from 2012 and answers percent value of obese adults 
# total adult obesity per state in 2012 
obese_sub = obese[(obese['YearStart']==2012) & 
      (obese['Question'] == 'Percent of adults aged 18 years and older who have obesity') &
      ~(obese['LocationAbbr'].isin(['US', 'DC'])) &
      (obese['StratificationCategory1'] == 'Total')][['LocationDesc', 'Data_Value']]

# %%
obese_sub.rename(columns={'LocationDesc':'StateName', 'Data_Value':'total_adult_obesity_percent'}, inplace=True)

# %%
geo_agri = agri_df['County Names'][['FIPSTEXT', 'StateName']]

# %%
var_lookup = agri_df['Variable Lookup']
sugar_mid = (var_lookup[var_lookup['MAPTITLE'].isin(['Acres of Sugarbeets for Sugar Harvested as Percent of Harvested Cropland Acreage:  2012',
                                                        'Acres of Sugarcane for Sugar Harvested as Percent of Harvested Cropland Acreage:  2012'])]['MapID']).values

# %%
sugar_mid
# Out:
# array(['y12_M328', 'y12_M329'], dtype=object)

# %%
sugar = agri_df['Crops and Plants'][['FIPSTEXT','y12_M328_valueNumeric', 'y12_M329_valueNumeric']]

# %%
# merge and remove NA values for State 
sugar = pd.merge(sugar, geo_agri, on="FIPSTEXT", how="left")
sugar = sugar[~sugar['StateName'].isna()]

# %%
# fill in NA values with zero 
sugar.fillna(0, inplace=True)
# Out:
# /Users/Nina/bin/anaconda3/envs/msds622/lib/python3.7/site-packages/pandas/core/frame.py:3790: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# aggregating and renaming 
sugar_agg = sugar.copy()
sugar_agg.drop(columns="FIPSTEXT", inplace=True)
sugar_agg = sugar_agg.groupby(by='StateName').sum().reset_index()
sugar_agg.rename(columns={'y12_M328_valueNumeric': 'sum_acre_sugar_sugarbeets',
                          'y12_M329_valueNumeric':'sum_acre_sugar_sugarcane'}, inplace=True)

# %%
sugar_agg['combined_sugar_acres'] = sugar_agg['sum_acre_sugar_sugarbeets'] + sugar_agg['sum_acre_sugar_sugarcane']

# %%
sugar_agg
# Out:
#          StateName  sum_acre_sugar_sugarbeets  sum_acre_sugar_sugarcane  \
# 0          Alabama                       0.00                      0.00
# 1           Alaska                       0.00                      0.00
# 2          Arizona                       0.00                      0.00
# 3         Arkansas                       0.00                      0.00
# 4       California                       0.00                      0.00
# 5         Colorado                      13.30                      0.00
# 6      Connecticut                       0.00                      0.00
# 7         Delaware                       0.00                      0.00
# 8          Florida                       0.00                    187.66
# 9          Georgia                       0.00                      0.00
# 10          Hawaii                       0.00                      0.11
# 11           Idaho                     106.39                      0.00
# 12        Illinois                       0.00                      0.00
# 13         Indiana                       0.00                      0.00
# 14            Iowa                       0.00                      0.00
# 15          Kansas                       0.00                      0.00
# 16        Kentucky                       0.00                      0.00
# 17        Louisana                       0.00                    849.26
# 18           Maine                       0.00                      0.00
# 19        Maryland                       0.00                      0.00
# 20   Massachusetts                       0.00                      0.00
# 21        Michigan                      62.44                      0.00
# 22       Minnesota                     105.96                      0.00
# 23     Mississippi                       0.00                      0.00
# 24        Missouri                       0.00                      0.00
# 25         Montana                      33.81                      0.00
# 26        Nebraska                      22.59                      0.00
# 27          Nevada                       0.00                      0.00
# 28   New Hampshire                       0.00                      0.00
# 29      New Jersey                       0.00                      0.00
# 30      New Mexico                       0.00                      0.00
# 31        New York                       0.00                      0.00
# 32  North Carolina                       0.00                      0.00
# 33    North Dakota                      36.85                      0.00
# 34            Ohio                       0.00                      0.00
# 35        Oklahoma                       0.00                      0.00
# 36          Oregon                       5.27                      0.00
# 37    Pennsylvania                       0.00                      0.00
# 38    Rhode Island                       0.00                      0.00
# 39  South Carolina                       0.00                      0.00
# 40    South Dakota                       0.00                      0.00
# 41       Tennessee                       0.00                      0.00
# 42           Texas                       0.00                     16.03
# 43            Utah                       0.00                      0.00
# 44         Vermont                       0.01                      0.00
# 45        Virginia                       0.00                      0.00
# 46      Washington                       0.00                      0.00
# 47   West Virginia                       0.00                      0.00
# 48       Wisconsin                       0.00                      0.00
# 49         Wyoming                      42.13                      0.00
#
#     combined_sugar_acres
# 0                   0.00
# 1                   0.00
# 2                   0.00
# 3                   0.00
# 4                   0.00
# 5                  13.30
# 6                   0.00
# 7                   0.00
# 8                 187.66
# 9                   0.00
# 10                  0.11
# 11                106.39
# 12                  0.00
# 13                  0.00
# 14                  0.00
# 15                  0.00
# 16                  0.00
# 17                849.26
# 18                  0.00
# 19                  0.00
# 20                  0.00
# 21                 62.44
# 22                105.96
# 23                  0.00
# 24                  0.00
# 25                 33.81
# 26                 22.59
# 27                  0.00
# 28                  0.00
# 29                  0.00
# 30                  0.00
# 31                  0.00
# 32                  0.00
# 33                 36.85
# 34                  0.00
# 35                  0.00
# 36                  5.27
# 37                  0.00
# 38                  0.00
# 39                  0.00
# 40                  0.00
# 41                  0.00
# 42                 16.03
# 43                  0.00
# 44                  0.01
# 45                  0.00
# 46                  0.00
# 47                  0.00
# 48                  0.00
# 49                 42.13

# %%
# joining sugar and obesity data 
sug_ob = pd.merge(sugar_agg, obese_sub, on="StateName", how="inner")

# %%
ob = sug_ob['total_adult_obesity_percent']

# %%
sorted(ob)
# Out:
# [20.5,
#  22.9,
#  23.6,
#  23.6,
#  23.7,
#  24.3,
#  24.3,
#  24.6,
#  24.6,
#  25.0,
#  25.2,
#  25.6,
#  25.7,
#  25.7,
#  25.7,
#  26.0,
#  26.2,
#  26.8,
#  26.8,
#  26.9,
#  27.1,
#  27.3,
#  27.3,
#  27.4,
#  27.6,
#  28.1,
#  28.1,
#  28.3,
#  28.6,
#  29.1,
#  29.1,
#  29.2,
#  29.6,
#  29.6,
#  29.7,
#  29.7,
#  29.8,
#  30.1,
#  30.4,
#  31.1,
#  31.1,
#  31.3,
#  31.4,
#  31.6,
#  32.2,
#  33.0,
#  33.8,
#  34.5,
#  34.6]

# %%
sug_ob
# Out:
#          StateName  sum_acre_sugar_sugarbeets  sum_acre_sugar_sugarcane  \
# 0          Alabama                       0.00                      0.00
# 1           Alaska                       0.00                      0.00
# 2          Arizona                       0.00                      0.00
# 3         Arkansas                       0.00                      0.00
# 4       California                       0.00                      0.00
# 5         Colorado                      13.30                      0.00
# 6      Connecticut                       0.00                      0.00
# 7         Delaware                       0.00                      0.00
# 8          Florida                       0.00                    187.66
# 9          Georgia                       0.00                      0.00
# 10          Hawaii                       0.00                      0.11
# 11           Idaho                     106.39                      0.00
# 12        Illinois                       0.00                      0.00
# 13         Indiana                       0.00                      0.00
# 14            Iowa                       0.00                      0.00
# 15          Kansas                       0.00                      0.00
# 16        Kentucky                       0.00                      0.00
# 17           Maine                       0.00                      0.00
# 18        Maryland                       0.00                      0.00
# 19   Massachusetts                       0.00                      0.00
# 20        Michigan                      62.44                      0.00
# 21       Minnesota                     105.96                      0.00
# 22     Mississippi                       0.00                      0.00
# 23        Missouri                       0.00                      0.00
# 24         Montana                      33.81                      0.00
# 25        Nebraska                      22.59                      0.00
# 26          Nevada                       0.00                      0.00
# 27   New Hampshire                       0.00                      0.00
# 28      New Jersey                       0.00                      0.00
# 29      New Mexico                       0.00                      0.00
# 30        New York                       0.00                      0.00
# 31  North Carolina                       0.00                      0.00
# 32    North Dakota                      36.85                      0.00
# 33            Ohio                       0.00                      0.00
# 34        Oklahoma                       0.00                      0.00
# 35          Oregon                       5.27                      0.00
# 36    Pennsylvania                       0.00                      0.00
# 37    Rhode Island                       0.00                      0.00
# 38  South Carolina                       0.00                      0.00
# 39    South Dakota                       0.00                      0.00
# 40       Tennessee                       0.00                      0.00
# 41           Texas                       0.00                     16.03
# 42            Utah                       0.00                      0.00
# 43         Vermont                       0.01                      0.00
# 44        Virginia                       0.00                      0.00
# 45      Washington                       0.00                      0.00
# 46   West Virginia                       0.00                      0.00
# 47       Wisconsin                       0.00                      0.00
# 48         Wyoming                      42.13                      0.00
#
#     combined_sugar_acres  total_adult_obesity_percent
# 0                   0.00                         33.0
# 1                   0.00                         25.7
# 2                   0.00                         26.0
# 3                   0.00                         34.5
# 4                   0.00                         25.0
# 5                  13.30                         20.5
# 6                   0.00                         25.6
# 7                   0.00                         26.9
# 8                 187.66                         25.2
# 9                   0.00                         29.1
# 10                  0.11                         23.6
# 11                106.39                         26.8
# 12                  0.00                         28.1
# 13                  0.00                         31.4
# 14                  0.00                         30.4
# 15                  0.00                         29.8
# 16                  0.00                         31.3
# 17                  0.00                         28.3
# 18                  0.00                         27.6
# 19                  0.00                         22.9
# 20                 62.44                         31.1
# 21                105.96                         25.7
# 22                  0.00                         34.6
# 23                  0.00                         29.6
# 24                 33.81                         24.3
# 25                 22.59                         28.6
# 26                  0.00                         26.2
# 27                  0.00                         27.3
# 28                  0.00                         24.6
# 29                  0.00                         27.1
# 30                  0.00                         23.6
# 31                  0.00                         29.6
# 32                 36.85                         29.7
# 33                  0.00                         30.1
# 34                  0.00                         32.2
# 35                  5.27                         27.3
# 36                  0.00                         29.1
# 37                  0.00                         25.7
# 38                  0.00                         31.6
# 39                  0.00                         28.1
# 40                  0.00                         31.1
# 41                 16.03                         29.2
# 42                  0.00                         24.3
# 43                  0.01                         23.7
# 44                  0.00                         27.4
# 45                  0.00                         26.8
# 46                  0.00                         33.8
# 47                  0.00                         29.7
# 48                 42.13                         24.6

# %%
sug_ob.to_csv('sugar_obesity_2012.csv', index=False)
