# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Data Processing

# %%
gas = pd.read_csv('./data/green_house_gases.csv')
food = pd.read_csv('./data/food_waste.csv')

# %%
gas.head()
# Out:
#    COU    Country  POL         Pollutant    VAR  \
# 0  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 1  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 2  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 3  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 4  AUS  Australia  GHG  Greenhouse gases  TOTAL
#
#                             Variable   YEA  Year   Unit Code  \
# 0  Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1  Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# 2  Total  emissions excluding LULUCF  1992  1992  T_CO2_EQVT
# 3  Total  emissions excluding LULUCF  1993  1993  T_CO2_EQVT
# 4  Total  emissions excluding LULUCF  1994  1994  T_CO2_EQVT
#
#                        Unit  PowerCode Code  PowerCode  Reference Period Code  \
# 0  Tonnes of CO2 equivalent               3  Thousands                    NaN
# 1  Tonnes of CO2 equivalent               3  Thousands                    NaN
# ...

# %%
food.head()
# Out:
#   LOCATION  Country   CAT                   Category                     ACT  \
# 0      DNK  Denmark  FLFW  1. Food loss - Food waste  AGRICULTURALPRODUCTION
# 1      NOR   Norway  FLFW  1. Food loss - Food waste               PRODUCERS
# 2      DNK  Denmark  FLFW  1. Food loss - Food waste            FOODINDUSTRY
# 3      DNK  Denmark  FLFW  1. Food loss - Food waste            FOODINDUSTRY
# 4      DEU  Germany  FLFW  1. Food loss - Food waste            FOODINDUSTRY
#
#                   Activity        UNIT       Unit       VAR  \
# 0  Agricultural production  KGBYCAPITA  kg/capita  FWVAR511
# 1                Producers  KGBYCAPITA  kg/capita  FWVAR213
# 2            Food Industry  KGBYCAPITA  kg/capita  FWVAR511
# 3            Food Industry  KGBYCAPITA  kg/capita  FWVAR262
# 4            Food Industry  KGBYCAPITA  kg/capita  FWVAR213
#
#                              Variable       SRC  \
# 0  Unnecessary edible food waste (e.)  SOURCE22
# ...

# %%
set(gas['Unit'])
# Out:
# {'Index',
#  'Kilograms per 1 000 US dollars',
#  'Kilograms per capita',
#  'Tonnes of CO2 equivalent',
#  nan}

# %%
set(food['Unit'])
# Out:
# {'kg/capita'}

# %%
# filter gas data to include only Kilograms per capita
gas = gas[gas['Unit'] == 'Kilograms per capita']

# %%
len(gas)
# Out:
# 1127

# %%
len(food)
# Out:
# 210

# %%
food
# Out:
#     LOCATION        Country   CAT                   Category  \
# 0        DNK        Denmark  FLFW  1. Food loss - Food waste
# 1        NOR         Norway  FLFW  1. Food loss - Food waste
# 2        DNK        Denmark  FLFW  1. Food loss - Food waste
# 3        DNK        Denmark  FLFW  1. Food loss - Food waste
# 4        DEU        Germany  FLFW  1. Food loss - Food waste
# 5        SWE         Sweden  FLFW  1. Food loss - Food waste
# 6        USA  United States  FLFW  1. Food loss - Food waste
# 7        USA  United States  FLFW  1. Food loss - Food waste
# 8        USA  United States  FLFW  1. Food loss - Food waste
# 9        USA  United States  FLFW  1. Food loss - Food waste
# 10       USA  United States  FLFW  1. Food loss - Food waste
# 11       USA  United States  FLFW  1. Food loss - Food waste
# 12       USA  United States  FLFW  1. Food loss - Food waste
# 13       USA  United States  FLFW  1. Food loss - Food waste
# ...

# %%
food['Time'].mode()
# Out:
# 0    2010
# dtype: int64

# %%
set(food['Category'])
# Out:
# {'1. Food loss - Food waste'}

# %%
set(food['Activity'])
# Out:
# {'Agricultural production',
#  'Combined : Post-production and Pre-consumption',
#  'Combined: Eurostat proxy for manufacturing of food products - includes tobacco',
#  'Combined: Eurostat proxy for services',
#  'Food Industry',
#  'Grocery stores',
#  'Households',
#  'Industrial kitchens',
#  'Producers',
#  'Restaurants',
#  'Retail',
#  'School cantines',
#  'Total',
#  'Wholesale',
#  'Wholesale & Retail'}

# %%
set(gas['Country'])
# Out:
# {'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Chile',
#  "China (People's Republic of)",
#  'Colombia',
#  'Costa Rica',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Korea',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Mexico',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'OECD - Europe',
#  'OECD - Total',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Slovak Republic',
#  'Slovenia',
#  'South Africa',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'United Kingdom',
#  'United States'}

# %%
set(food['Activity'])
# Out:
# {'Agricultural production',
#  'Combined : Post-production and Pre-consumption',
#  'Combined: Eurostat proxy for manufacturing of food products - includes tobacco',
#  'Combined: Eurostat proxy for services',
#  'Food Industry',
#  'Grocery stores',
#  'Households',
#  'Industrial kitchens',
#  'Producers',
#  'Restaurants',
#  'Retail',
#  'School cantines',
#  'Total',
#  'Wholesale',
#  'Wholesale & Retail'}

# %%
food_new = food.drop(columns=['LOCATION', 'TIME', 'Flag Codes', 'Flags'])

# %%
food_new
# Out:
#            Country   CAT                   Category  \
# 0          Denmark  FLFW  1. Food loss - Food waste
# 1           Norway  FLFW  1. Food loss - Food waste
# 2          Denmark  FLFW  1. Food loss - Food waste
# 3          Denmark  FLFW  1. Food loss - Food waste
# 4          Germany  FLFW  1. Food loss - Food waste
# 5           Sweden  FLFW  1. Food loss - Food waste
# 6    United States  FLFW  1. Food loss - Food waste
# 7    United States  FLFW  1. Food loss - Food waste
# 8    United States  FLFW  1. Food loss - Food waste
# 9    United States  FLFW  1. Food loss - Food waste
# 10   United States  FLFW  1. Food loss - Food waste
# 11   United States  FLFW  1. Food loss - Food waste
# 12   United States  FLFW  1. Food loss - Food waste
# 13   United States  FLFW  1. Food loss - Food waste
# 14   United States  FLFW  1. Food loss - Food waste
# 15   United States  FLFW  1. Food loss - Food waste
# 16   United States  FLFW  1. Food loss - Food waste
# ...

# %%
food_agg = food_new.groupby(['Country', 'Time']).sum().reset_index()

# %%
food_agg
# Out:
#             Country  Time        Value
# 0         Australia  2009   126.000000
# 1           Austria  2006    95.000000
# 2           Belgium  2004    27.000000
# 3           Belgium  2010    95.000000
# 4            Canada  2009   122.000000
# 5            Canada  2010   122.530000
# 6           Denmark  2006    91.000000
# 7           Denmark  2011   343.778700
# 8           Estonia  2006    61.000000
# 9           Finland  2006    41.000000
# 10          Finland  2009    17.000000
# 11           France  2007    27.000000
# 12          Germany  2011   101.116137
# 13           Greece  2006    37.000000
# 14          Hungary  2006    39.000000
# 15          Ireland  2006    69.000000
# 16            Korea  2004    87.239000
# 17            Korea  2005    98.270000
# 18            Korea  2006   101.276000
# 19            Korea  2007   109.297000
# 20            Korea  2008   113.309000
# 21            Korea  2009   105.287000
# 22            Korea  2010   101.277000
# ...

# %%
food_agg.rename(columns={'Time':'Year'}, inplace=True)
food_agg.rename(columns={'Value':'food_waste'}, inplace=True)

# %%
food_agg.head()
# Out:
#      Country  Year  food_waste
# 0  Australia  2009       126.0
# 1    Austria  2006        95.0
# 2    Belgium  2004        27.0
# 3    Belgium  2010        95.0
# 4     Canada  2009       122.0

# %%
combo = gas.merge(food_agg, how = 'inner', on=['Country', 'Year'])

# %%
len(combo)
# Out:
# 60

# %%
combo
# Out:
#     COU          Country  POL         Pollutant      VAR  \
# 0   AUS        Australia  GHG  Greenhouse gases  GHG_CAP
# 1   AUT          Austria  GHG  Greenhouse gases  GHG_CAP
# 2   BEL          Belgium  GHG  Greenhouse gases  GHG_CAP
# 3   BEL          Belgium  GHG  Greenhouse gases  GHG_CAP
# 4   CAN           Canada  GHG  Greenhouse gases  GHG_CAP
# 5   CAN           Canada  GHG  Greenhouse gases  GHG_CAP
# 6   DNK          Denmark  GHG  Greenhouse gases  GHG_CAP
# 7   DNK          Denmark  GHG  Greenhouse gases  GHG_CAP
# 8   FIN          Finland  GHG  Greenhouse gases  GHG_CAP
# 9   FIN          Finland  GHG  Greenhouse gases  GHG_CAP
# 10  FRA           France  GHG  Greenhouse gases  GHG_CAP
# 11  DEU          Germany  GHG  Greenhouse gases  GHG_CAP
# 12  GRC           Greece  GHG  Greenhouse gases  GHG_CAP
# 13  HUN          Hungary  GHG  Greenhouse gases  GHG_CAP
# 14  IRL          Ireland  GHG  Greenhouse gases  GHG_CAP
# ...

# %%
set(combo['Pollutant'])
# Out:
# {'Greenhouse gases'}

# %%
set(combo['Variable'])
# Out:
# {'Total GHG excl. LULUCF per capita'}

# %%
data_2010 = combo[combo['Year'] == 2010]

# %%
data_2010
# Out:
#     COU        Country  POL         Pollutant      VAR  \
# 3   BEL        Belgium  GHG  Greenhouse gases  GHG_CAP
# 5   CAN         Canada  GHG  Greenhouse gases  GHG_CAP
# 21  KOR          Korea  GHG  Greenhouse gases  GHG_CAP
# 41  NLD    Netherlands  GHG  Greenhouse gases  GHG_CAP
# 45  PRT       Portugal  GHG  Greenhouse gases  GHG_CAP
# 51  SWE         Sweden  GHG  Greenhouse gases  GHG_CAP
# 58  USA  United States  GHG  Greenhouse gases  GHG_CAP
#
#                              Variable   YEA  Year Unit Code  \
# 3   Total GHG excl. LULUCF per capita  2010  2010    KG_HAB
# 5   Total GHG excl. LULUCF per capita  2010  2010    KG_HAB
# 21  Total GHG excl. LULUCF per capita  2010  2010    KG_HAB
# 41  Total GHG excl. LULUCF per capita  2010  2010    KG_HAB
# 45  Total GHG excl. LULUCF per capita  2010  2010    KG_HAB
# 51  Total GHG excl. LULUCF per capita  2010  2010    KG_HAB
# 58  Total GHG excl. LULUCF per capita  2010  2010    KG_HAB
#
# ...

# %%
data_2010.to_csv('./data/data_2010.csv', index=False)

# %%
nld.to_csv('./data/nld.csv', index=False)
